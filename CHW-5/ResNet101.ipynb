# %%
from keras.applications import ResNet101
from keras.models import Model
from keras.layers import GlobalAveragePooling2D
from keras.preprocessing import image
from keras.applications.resnet import preprocess_input, decode_predictions
import numpy as np

import zipfile
import os

# %%
# !wget -O cats_and_dogs_filtered.zip  "https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip"
# Out:
# --2024-02-06 11:17:05--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.123.207, 142.250.97.207, 74.125.196.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.123.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   147MB/s    in 0.4s
#
# 2024-02-06 11:17:06 (147 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# Extract the contents of the ZIP file
with zipfile.ZipFile("cats_and_dogs_filtered.zip", "r") as zip_ref:
    zip_ref.extractall("data")

# %%
from PIL import Image

# Open the JPEG image
train_cat = []
train_dog = []
num_test = 500;
for i in range(2*num_test):
  if i%10 == 0:
    print("i = ",i)
  link_train_cat = "data/cats_and_dogs_filtered/train/cats/cat."+str(i)+".jpg"
  train_cat.append(feature(link_train_cat));


for i in range(2*num_test):
  if i%10 == 0:
    print("i = ",i)
  link_train_dog = "data/cats_and_dogs_filtered/train/dogs/dog."+str(i)+".jpg"
  train_dog.append(feature(link_train_dog));
# Out:
# i =  0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e691d945990> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e691d5343a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  10
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  20
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  30
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  40
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  50
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  60
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  70
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  80
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  90
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  100
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  110
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  120
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  130
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  140
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  150
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  160
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  170
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  180
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  190
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  200
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  210
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  220
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  230
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  240
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  250
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  260
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  270
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  280
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  290
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  300
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  310
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  320
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  330
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  340
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  350
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  360
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  370
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  380
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  390
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  400
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  410
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  420
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  430
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  440
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  450
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  460
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  470
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  480
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  490
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  500
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  510
# ...
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  0
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  10
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  20
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  30
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  40
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  50
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fd86fea456c6> in <cell line: 22>()
#      24     print("i = ",i)
#      25     link_test_cat = "data/cats_and_dogs_filtered/test/cats/cat."+str(i)+".jpg"
# ---> 26     test_cat.append(feature(link_train_cat));
#      27
#      28 for i in range(num_test):
#
# <ipython-input-5-8c6e09fd5cef> in feature(img_path)
#      17
#      18   # Get the features from the last layer
# ---> 19   last_layer_features = model.predict(img_array);
#      20   # Display the shape of the last layer features
#      21   print("Shape of last layer features:", last_layer_features.shape)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2653                     for step in data_handler.steps():
#    2654                         callbacks.on_predict_batch_begin(step)
# -> 2655                         tmp_batch_outputs = self.predict_function(iterator)
#    2656                         if data_handler.should_sync:
#    2657                             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     886       # This is the first call of __call__, so we have to initialize.
#     887       initializers = []
# --> 888       self._initialize(args, kwds, add_initializers_to=initializers)
#     889     finally:
#     890       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     693     )
#     694     # Force the definition of the function for these arguments
# --> 695     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696         args, kwds, self._variable_creation_config
#     697     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         # the function a weak reference to itself to avoid a reference cycle.
#     597         with OptionalXlaContext(compile_with_xla):
# --> 598           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599         return out
#     600
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     458   if kwargs is not None:
#     459     return f(*args, **kwargs)
# --> 460   return f(*args)
#     461
#     462
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in step_function(model, iterator)
#    2423
#    2424             data = next(iterator)
# -> 2425             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    2426             outputs = reduce_per_replica(
#    2427                 outputs, self.distribute_strategy, reduction="concat"
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1679       fn = autograph.tf_convert(
#    1680           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1682
#    1683   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    3269       kwargs = {}
#    3270     with self._container_strategy().scope():
# -> 3271       return self._call_for_each_replica(fn, args, kwargs)
#    3272
#    3273   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    4067   def _call_for_each_replica(self, fn, args, kwargs):
#    4068     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069       return fn(*args, **kwargs)
#    4070
#    4071   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(data)
#    2411
#    2412             def run_step(data):
# -> 2413                 outputs = model.predict_step(data)
#    2414                 # Ensure counter is updated only if `test_step` succeeds.
#    2415                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict_step(self, data)
#    2379         """
#    2380         x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 2381         return self(x, training=False)
#    2382
#    2383     def make_predict_function(self, force=False):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in __call__(self, *args, **kwargs)
#     588             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     589
# --> 590         return super().__call__(*args, **kwargs)
#     591
#     592     @doc_controls.doc_in_current_and_subclasses
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329   if conversion.is_in_allowlist_cache(f, options):
#     330     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331     return _call_unconverted(f, args, kwargs, options, False)
#     332
#     333   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in call(self, inputs, training, mask)
#     513             a list of tensors if there are more than one outputs.
#     514         """
# --> 515         return self._run_internal_graph(inputs, training=training, mask=mask)
#     516
#     517     def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     670
#     671                 args, kwargs = node.map_arguments(tensor_dict)
# --> 672                 outputs = node.layer(*args, **kwargs)
#     673
#     674                 # Update tensor_dict.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1123             else:
#    1124                 name_scope = self._get_unnested_name_scope()
# -> 1125                 call_fn = self._autographed_call()
#    1126
#    1127             call_fn = traceback_utils.inject_argument_info_in_traceback(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _autographed_call(self)
#    2681             self
#    2682         ) and not base_layer_utils.from_saved_model(self):
# -> 2683             return tf.__internal__.autograph.tf_convert(
#    2684                 self.call, tf.__internal__.autograph.control_status_ctx()
#    2685             )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in tf_convert(f, ctx, convert_by_default, user_requested)
#     554   """
#     555
# --> 556   if is_autograph_artifact(f):
#     557     return f
#     558   f_wrapper = f
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in is_autograph_artifact(entity)
#     290
#     291 def is_autograph_artifact(entity):
# --> 292   return hasattr(entity, 'autograph_info__')
#     293
#     294
#
# KeyboardInterrupt:

# %%
# Out:
# (1000, 1, 2048)

# %%
test_cat = []
test_dog = []

for i in np.arange(2000,2500):
  if i%10 == 0:
    print("i = ",i)
  link_test_cat = "data/cats_and_dogs_filtered/validation/cats/cat."+str(i)+".jpg"
  test_cat.append(feature(link_test_cat));

for i in np.arange(2000,2500):
  if i%10 == 0:
    print("i = ",i)
  link_test_dog = "data/cats_and_dogs_filtered/validation/dogs/dog."+str(i)+".jpg"
  test_dog.append(feature(link_test_dog));
# Out:
# i =  2000
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2010
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2020
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2030
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2040
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2050
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2060
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2070
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2080
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2090
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2100
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2110
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2120
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2130
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2140
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2150
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2160
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2170
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2180
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2190
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2200
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2210
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2220
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2230
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2240
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  2250
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2260
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2270
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2280
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2290
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2300
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2310
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2320
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2330
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2340
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2350
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  2360
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2370
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2380
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2390
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2400
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2410
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2420
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2430
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2440
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2450
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2460
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2470
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2480
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2490
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  2000
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2010
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2020
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# ...
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2330
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2340
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 5s 5s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2350
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  2360
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2370
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2380
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2390
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  2400
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2410
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2420
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2430
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2440
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2450
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# i =  2460
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# i =  2470
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2480
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# i =  2490
# 1/1 [==============================] - 2s 2s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 4s 4s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)
# 1/1 [==============================] - 3s 3s/step
# Shape of last layer features: (1, 2048)

# %%
def feature(img_path):
  # Load the ResNet101 model with weights pre-trained on ImageNet
  base_model = ResNet101(weights='imagenet', include_top=False);

  # Add Global Average Pooling layer
  x = GlobalAveragePooling2D()(base_model.output);

  # Create a model that includes the ResNet101 base model and GAP layer
  model = Model(inputs=base_model.input, outputs=x);

  # Load an example image (replace 'path/to/your/image.jpg' with the actual path)

  img = image.load_img(img_path, target_size=(224, 224));
  img_array = image.img_to_array(img);
  img_array = np.expand_dims(img_array, axis=0);
  img_array = preprocess_input(img_array);

  # Get the features from the last layer
  last_layer_features = model.predict(img_array);
  # Display the shape of the last layer features
  print("Shape of last layer features:", last_layer_features.shape)
  return last_layer_features

# %%
X_train = np.array(train_cat + train_dog);
X_train = np.reshape(X_train,[X_train.shape[0],-1]);
print(X_train.shape)

X_test = np.array(test_cat + test_dog);
X_test = np.reshape(X_test,[X_test.shape[0],-1]);
print(X_test.shape)

y_train = np.concatenate((np.array(np.ones(1000)), np.array(np.zeros(1000))))
y_test =np.concatenate((np.array(np.ones(500)), np.array(np.zeros(500))))
# Out:
# (2000, 2048)
# (1000, 2048)

# %%
# Import necessary libraries
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)

# Predict on the test set
y_pred = svm_classifier.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)*100
print("Accuracy of ResNet:", accuracy)
# Out:
# Accuracy of ResNet: 99.1

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have trained your SVM classifier and obtained predictions
# Replace y_true with true labels and y_pred with predicted labels
# y_true and y_pred should be arrays of the same length containing the true and predicted labels, respectively

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
np.save('y_predResNet', y_pred)
